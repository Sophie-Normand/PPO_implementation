# %% [markdown]
# > # **Install Dependencies**

# %%
# install compatible version of gym environments
# !pip install swig
# !pip install roboschool==1.0.7 gym==0.15.4
# !pip install box2d-py
# !pip install Box2D
# !pip install pybullet
# !pip install gym[box2d]
# Out:
# Requirement already satisfied: swig in /opt/anaconda3/lib/python3.8/site-packages (4.1.1)
# Collecting roboschool==1.0.7
#   Using cached roboschool-1.0.7.tar.gz (12.0 MB)
# Requirement already satisfied: gym==0.15.4 in /opt/anaconda3/lib/python3.8/site-packages (0.15.4)
# Requirement already satisfied: numpy>=1.10.4 in /opt/anaconda3/lib/python3.8/site-packages (from gym==0.15.4) (1.23.4)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from gym==0.15.4) (1.3.2)
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.8/site-packages (from gym==0.15.4) (4.5.3.56)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from gym==0.15.4) (1.15.0)
# Requirement already satisfied: cloudpickle~=1.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from gym==0.15.4) (1.2.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.8/site-packages (from gym==0.15.4) (1.8.1)
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.8/site-packages (from pyglet<=1.3.2,>=1.2.0->gym==0.15.4) (0.18.2)
# Building wheels for collected packages: roboschool
#   Building wheel for roboschool (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/setup.py'"'"'; __file__='"'"'/private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-wheel-x10qrmmj
#        cwd: /private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/
#   Complete output (387 lines):
#   found resource files: 161
#   -- cpp_household.so
#   -- models_household/ball.urdf
#   -- models_household/cube.urdf
#   -- models_household/duck/duckCM.jpg
#   -- models_household/duck/duck.dae
#   -- models_household/dinnerware/pan_tefal.jpg
#   -- models_household/dinnerware/pan_tefal-collision06.obj
#   -- models_household/dinnerware/dinnerware.mtl
#   -- models_household/dinnerware/pan_tefal-collision04.obj
#   -- models_household/dinnerware/pan_tefal-collision05.obj
#   -- models_household/dinnerware/pan_tefal-collision01.obj
#   -- models_household/dinnerware/pan_tefal-collision02.obj
#   -- models_household/dinnerware/pan_tefal-collision03.obj
#   -- models_household/dinnerware/pan_tefal.obj
#   -- models_household/dinnerware/plate-collision04.obj
#   -- models_household/dinnerware/plate-collision05.obj
#   -- models_household/dinnerware/plate-collision06.obj
#   -- models_household/dinnerware/plate.urdf
#   -- models_household/dinnerware/plate-collision02.obj
#   -- models_household/dinnerware/plate-collision03.obj
#   -- models_household/dinnerware/plate.obj
#   -- models_household/dinnerware/plate-collision01.obj
#   -- models_household/dinnerware/pan_tefal.urdf
#   -- models_household/woodenbox/woodenbox-collision08.off
#   -- models_household/woodenbox/woodenbox.obj
#   -- models_household/woodenbox/woodenbox-collision09.off
#   -- models_household/woodenbox/woodenbox-collision10.off
#   -- models_household/woodenbox/woodenbox-collision04.off
#   -- models_household/woodenbox/woodenbox_tex.jpg
#   -- models_household/woodenbox/woodenbox-collision05.off
#   -- models_household/woodenbox/woodenbox-collision07.off
#   -- models_household/woodenbox/woodenbox-collision06.off
#   -- models_household/woodenbox/woodenbox-collision02.off
#   -- models_household/woodenbox/woodenbox.mtl
#   -- models_household/woodenbox/woodenbox-collision03.off
#   -- models_household/woodenbox/woodenbox-collision01.off
#   -- models_household/woodenbox/woodenbox-collision00.off
#   -- models_household/tablelamp/tablelamp.obj
#   -- models_household/tablelamp/tablelamp-collision01.off
#   -- models_household/tablelamp/tablelamptex.jpg
#   -- models_household/tablelamp/tablelamp-collision00.off
#   -- models_household/tablelamp/tablelamp-collision02.off
#   -- models_household/tablelamp/tablelamp.obj.mtl
#   -- models_household/joypad/joypad.obj
#   -- models_household/joypad/joypad_tex.jpg
#   -- models_household/joypad/joypad.mtl
#   -- models_household/zucchini/zucchini_tex_green.jpg
#   -- models_household/zucchini/zucchini.obj
#   -- models_household/zucchini/zucchini.mtl
#   -- models_household/bottle/potionbottlesolid.mtl
#   -- models_household/bottle/potionbottleglass.obj
#   -- models_household/bottle/glasscontent_tex.jpg
#   -- models_household/bottle/bottle.urdf
#   -- models_household/bottle/glass_tex.png
#   -- models_household/bottle/potionbottlesolid.obj
#   -- models_household/bottle/potionbottleglass.mtl
#   -- models_household/keyboard/keyboard.obj
#   -- models_household/keyboard/keyboard.mtl
#   -- models_household/keyboard/keyboard_tex.jpg
#   -- models_outdoor/stadium/stadium1.obj
#   -- models_outdoor/stadium/stadium.mtl
#   -- models_outdoor/stadium/stadium_grass.jpg
#   -- models_outdoor/stadium/pong1.obj
#   -- mujoco_assets/reacher.xml
#   -- mujoco_assets/inverted_pendulum.xml
#   -- mujoco_assets/inverted_double_pendulum.xml
#   -- mujoco_assets/half_cheetah.xml
#   -- mujoco_assets/ant.xml
#   -- mujoco_assets/hopper.xml
#   -- mujoco_assets/humanoid_symmetric.xml
#   -- mujoco_assets/walker2d.xml
#   -- mujoco_assets/ground_plane.xml
#   -- models_robot/roboschool_pong.xml
#   -- models_robot/atlas_description/materials/textures/extremities_diffuse_unplugged.jpg
#   -- models_robot/atlas_description/materials/textures/right_leg_diffuse_unplugged.jpg
#   -- models_robot/atlas_description/materials/textures/drc_extremities_diffuse.jpg
#   -- models_robot/atlas_description/materials/textures/torso_diffuse_unplugged.jpg
#   -- models_robot/atlas_description/urdf/atlas_v4_with_multisense.urdf
#   -- models_robot/atlas_description/meshes_v3/r_farm.dae
#   -- models_robot/atlas_description/meshes_v3/r_larm.dae
#   -- models_robot/atlas_description/meshes_v3/r_hand.dae
#   -- models_robot/atlas_description/meshes_unplugged/l_lglut.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_scap.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_lglut.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_uleg.dae
#   -- models_robot/atlas_description/meshes_unplugged/pelvis.dae
#   -- models_robot/atlas_description/meshes_unplugged/l_uleg.dae
#   -- models_robot/atlas_description/meshes_unplugged/l_foot.dae
#   -- models_robot/atlas_description/meshes_unplugged/mtorso.dae
#   -- models_robot/atlas_description/meshes_unplugged/ltorso.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_talus.dae
#   -- models_robot/atlas_description/meshes_unplugged/l_talus.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_foot.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_clav.dae
#   -- models_robot/atlas_description/meshes_unplugged/utorso.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_lleg.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_uglut.dae
#   -- models_robot/atlas_description/meshes_unplugged/l_lleg.dae
#   -- models_robot/atlas_description/meshes_unplugged/l_uglut.dae
#   -- models_robot/atlas_description/meshes_unplugged/r_uarm.dae
#   -- models_robot/multisense_sl_description/materials/textures/drc_torso_head_diffuse.jpg
#   -- models_robot/multisense_sl_description/meshes/head.dae
#   -- models_robot/multisense_sl_description/meshes/head_camera.dae
#   -- models_robot/fetch_description/meshes/torso_lift_link_collision.STL
#   -- models_robot/fetch_description/meshes/l_wheel_link.STL
#   -- models_robot/fetch_description/meshes/bellows_link_collision.STL
#   -- models_robot/fetch_description/meshes/forearm_roll_link.dae
#   -- models_robot/fetch_description/meshes/r_wheel_link_collision.STL
#   -- models_robot/fetch_description/meshes/torso_fixed_link.dae
#   -- models_robot/fetch_description/meshes/gripper_uv.png
#   -- models_robot/fetch_description/meshes/shoulder_lift_link.dae
#   -- models_robot/fetch_description/meshes/head_pan_link.dae
#   -- models_robot/fetch_description/meshes/r_gripper_finger_link.STL
#   -- models_robot/fetch_description/meshes/bellows_link.STL
#   -- models_robot/fetch_description/meshes/elbow_flex_uv.png
#   -- models_robot/fetch_description/meshes/head_pan_uv.png
#   -- models_robot/fetch_description/meshes/l_gripper_finger_link.STL
#   -- models_robot/fetch_description/meshes/estop_link.STL
#   -- models_robot/fetch_description/meshes/torso_fixed_uv.png
#   -- models_robot/fetch_description/meshes/wrist_roll_uv.png
#   -- models_robot/fetch_description/meshes/wrist_flex_link.dae
#   -- models_robot/fetch_description/meshes/shoulder_lift_uv.png
#   -- models_robot/fetch_description/meshes/upperarm_roll_uv.png
#   -- models_robot/fetch_description/meshes/torso_lift_link.dae
#   -- models_robot/fetch_description/meshes/upperarm_roll_link.dae
#   -- models_robot/fetch_description/meshes/base_link.dae
#   -- models_robot/fetch_description/meshes/base_link_collision.STL
#   -- models_robot/fetch_description/meshes/shoulder_pan_uv.png
#   -- models_robot/fetch_description/meshes/gripper_link.dae
#   -- models_robot/fetch_description/meshes/torso_fixed_link.STL
#   -- models_robot/fetch_description/meshes/shoulder_pan_link_collision.STL
#   -- models_robot/fetch_description/meshes/forearm_roll_link_collision.STL
#   -- models_robot/fetch_description/meshes/upperarm_roll_link_collision.STL
#   -- models_robot/fetch_description/meshes/r_wheel_link.STL
#   -- models_robot/fetch_description/meshes/wrist_flex_uv.png
#   -- models_robot/fetch_description/meshes/wrist_roll_link_collision.STL
#   -- models_robot/fetch_description/meshes/elbow_flex_link.dae
#   -- models_robot/fetch_description/meshes/forearm_roll_uv.png
#   -- models_robot/fetch_description/meshes/gripper_link.STL
#   -- models_robot/fetch_description/meshes/head_pan_link_collision.STL
#   -- models_robot/fetch_description/meshes/laser_link.STL
#   -- models_robot/fetch_description/meshes/shoulder_lift_link_collision.STL
#   -- models_robot/fetch_description/meshes/torso_lift_uv.png
#   -- models_robot/fetch_description/meshes/head_tilt_uv.png
#   -- models_robot/fetch_description/meshes/wrist_roll_link.dae
#   -- models_robot/fetch_description/meshes/head_tilt_link.dae
#   -- models_robot/fetch_description/meshes/wrist_flex_link_collision.STL
#   -- models_robot/fetch_description/meshes/shoulder_pan_link.dae
#   -- models_robot/fetch_description/meshes/elbow_flex_link_collision.STL
#   -- models_robot/fetch_description/meshes/base_link_uv.png
#   -- models_robot/fetch_description/meshes/head_tilt_link_collision.STL
#   -- models_robot/fetch_description/meshes/l_wheel_link_collision.STL
#   -- models_robot/fetch_description/robots/fetch.urdf
#   -- cpp-household/glsl/simple_texturing.frag.glsl
#   -- cpp-household/glsl/ssao_hbao_blur.frag.glsl
#   -- cpp-household/glsl/fullscreen_triangle.vert.glsl
#   -- cpp-household/glsl/hud.vert.glsl
#   -- cpp-household/glsl/ssao_hbao.frag.glsl
#   -- cpp-household/glsl/displaytex.frag.glsl
#   -- cpp-household/glsl/simple_texturing.vert.glsl
#   -- cpp-household/glsl/ssao_depthlinearize.frag.glsl
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.8
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/multiplayer.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_atlas.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_urdf_robot_env.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_forward_walker.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_pong.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_humanoid_flagrun.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/random_stadium.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_mujoco_xml_env.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_mujoco_walkers.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_pong_trainservers.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/scene_stadium.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/scene_abstract.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_pendulums.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/gym_reacher.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   copying roboschool/test_manual.py -> build/lib.macosx-10.9-x86_64-3.8/roboschool
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household
#   copying roboschool/models_household/ball.urdf -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household
#   copying roboschool/models_household/cube.urdf -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/duck
#   copying roboschool/models_household/duck/duckCM.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/duck
#   copying roboschool/models_household/duck/duck.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/duck
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal-collision06.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/dinnerware.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal-collision04.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal-collision05.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal-collision01.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal-collision02.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal-collision03.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/plate-collision04.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/plate-collision05.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/plate-collision06.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/plate.urdf -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/plate-collision02.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/plate-collision03.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/plate.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/plate-collision01.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   copying roboschool/models_household/dinnerware/pan_tefal.urdf -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/dinnerware
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision08.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision09.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision10.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision04.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox_tex.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision05.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision07.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision06.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision02.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision03.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision01.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   copying roboschool/models_household/woodenbox/woodenbox-collision00.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/woodenbox
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/tablelamp
#   copying roboschool/models_household/tablelamp/tablelamp.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/tablelamp
#   copying roboschool/models_household/tablelamp/tablelamp-collision01.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/tablelamp
#   copying roboschool/models_household/tablelamp/tablelamptex.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/tablelamp
#   copying roboschool/models_household/tablelamp/tablelamp-collision00.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/tablelamp
#   copying roboschool/models_household/tablelamp/tablelamp-collision02.off -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/tablelamp
#   copying roboschool/models_household/tablelamp/tablelamp.obj.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/tablelamp
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/joypad
#   copying roboschool/models_household/joypad/joypad.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/joypad
#   copying roboschool/models_household/joypad/joypad_tex.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/joypad
#   copying roboschool/models_household/joypad/joypad.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/joypad
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/zucchini
#   copying roboschool/models_household/zucchini/zucchini_tex_green.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/zucchini
#   copying roboschool/models_household/zucchini/zucchini.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/zucchini
#   copying roboschool/models_household/zucchini/zucchini.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/zucchini
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/bottle
#   copying roboschool/models_household/bottle/potionbottlesolid.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/bottle
#   copying roboschool/models_household/bottle/potionbottleglass.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/bottle
#   copying roboschool/models_household/bottle/glasscontent_tex.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/bottle
#   copying roboschool/models_household/bottle/bottle.urdf -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/bottle
#   copying roboschool/models_household/bottle/glass_tex.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/bottle
#   copying roboschool/models_household/bottle/potionbottlesolid.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/bottle
#   copying roboschool/models_household/bottle/potionbottleglass.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/bottle
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/keyboard
#   copying roboschool/models_household/keyboard/keyboard.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/keyboard
#   copying roboschool/models_household/keyboard/keyboard.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/keyboard
#   copying roboschool/models_household/keyboard/keyboard_tex.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_household/keyboard
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_outdoor
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_outdoor/stadium
#   copying roboschool/models_outdoor/stadium/stadium1.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_outdoor/stadium
#   copying roboschool/models_outdoor/stadium/stadium.mtl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_outdoor/stadium
#   copying roboschool/models_outdoor/stadium/stadium_grass.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_outdoor/stadium
#   copying roboschool/models_outdoor/stadium/pong1.obj -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_outdoor/stadium
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/reacher.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/inverted_pendulum.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/inverted_double_pendulum.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/half_cheetah.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/ant.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/hopper.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/humanoid_symmetric.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/walker2d.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   copying roboschool/mujoco_assets/ground_plane.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/mujoco_assets
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot
#   copying roboschool/models_robot/roboschool_pong.xml -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/materials
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/materials/textures
#   copying roboschool/models_robot/atlas_description/materials/textures/extremities_diffuse_unplugged.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/materials/textures
#   copying roboschool/models_robot/atlas_description/materials/textures/right_leg_diffuse_unplugged.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/materials/textures
#   copying roboschool/models_robot/atlas_description/materials/textures/drc_extremities_diffuse.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/materials/textures
#   copying roboschool/models_robot/atlas_description/materials/textures/torso_diffuse_unplugged.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/materials/textures
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/urdf
#   copying roboschool/models_robot/atlas_description/urdf/atlas_v4_with_multisense.urdf -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/urdf
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_v3
#   copying roboschool/models_robot/atlas_description/meshes_v3/r_farm.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_v3
#   copying roboschool/models_robot/atlas_description/meshes_v3/r_larm.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_v3
#   copying roboschool/models_robot/atlas_description/meshes_v3/r_hand.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_v3
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/l_lglut.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_scap.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_lglut.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_uleg.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/pelvis.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/l_uleg.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/l_foot.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/mtorso.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/ltorso.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_talus.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/l_talus.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_foot.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_clav.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/utorso.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_lleg.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_uglut.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/l_lleg.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/l_uglut.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   copying roboschool/models_robot/atlas_description/meshes_unplugged/r_uarm.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/materials
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/materials/textures
#   copying roboschool/models_robot/multisense_sl_description/materials/textures/drc_torso_head_diffuse.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/materials/textures
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/meshes
#   copying roboschool/models_robot/multisense_sl_description/meshes/head.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/meshes
#   copying roboschool/models_robot/multisense_sl_description/meshes/head_camera.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/meshes
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/torso_lift_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/l_wheel_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/bellows_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/forearm_roll_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/r_wheel_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/torso_fixed_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/gripper_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/shoulder_lift_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/head_pan_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/r_gripper_finger_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/bellows_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/elbow_flex_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/head_pan_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/l_gripper_finger_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/estop_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/torso_fixed_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/wrist_roll_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/wrist_flex_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/shoulder_lift_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/upperarm_roll_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/torso_lift_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/upperarm_roll_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/base_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/base_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/shoulder_pan_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/gripper_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/torso_fixed_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/shoulder_pan_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/forearm_roll_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/upperarm_roll_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/r_wheel_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/wrist_flex_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/wrist_roll_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/elbow_flex_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/forearm_roll_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/gripper_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/head_pan_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/laser_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/shoulder_lift_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/torso_lift_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/head_tilt_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/wrist_roll_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/head_tilt_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/wrist_flex_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/shoulder_pan_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/elbow_flex_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/base_link_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/head_tilt_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   copying roboschool/models_robot/fetch_description/meshes/l_wheel_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/robots
#   copying roboschool/models_robot/fetch_description/robots/fetch.urdf -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/robots
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household
#   creating build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   copying roboschool/cpp-household/glsl/simple_texturing.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   copying roboschool/cpp-household/glsl/ssao_hbao_blur.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   copying roboschool/cpp-household/glsl/fullscreen_triangle.vert.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   copying roboschool/cpp-household/glsl/hud.vert.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   copying roboschool/cpp-household/glsl/ssao_hbao.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   copying roboschool/cpp-household/glsl/displaytex.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   copying roboschool/cpp-household/glsl/simple_texturing.vert.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   copying roboschool/cpp-household/glsl/ssao_depthlinearize.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#   running build_ext
#   cd /private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/roboschool/cpp-household && make clean && make -j4 dirs  ../cpp_household.so
#   make: *** No rule to make target `clean'.  Stop.
#
#   C++ dependencies for this project are:
#
#   bullet
#   tinyxml
#   boost_python
#   assimp
#   Qt5
#
#   If you see compilation error FIRST THING TO CHECK if pkg-config call was successful.
#   Install dependencies that pkg-config cannot find.
#
#   ----------------------------------------
#   ERROR: Failed building wheel for roboschool
#   Running setup.py clean for roboschool
# Failed to build roboschool
# Installing collected packages: roboschool
#     Running setup.py install for roboschool ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/setup.py'"'"'; __file__='"'"'/private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-record-abz7j5qh/install-record.txt --single-version-externally-managed --compile --install-headers /opt/anaconda3/include/python3.8/roboschool
#          cwd: /private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/
#     Complete output (387 lines):
#     found resource files: 161
#     -- cpp_household.so
#     -- models_household/ball.urdf
#     -- models_household/cube.urdf
#     -- models_household/duck/duckCM.jpg
#     -- models_household/duck/duck.dae
#     -- models_household/dinnerware/pan_tefal.jpg
#     -- models_household/dinnerware/pan_tefal-collision06.obj
#     -- models_household/dinnerware/dinnerware.mtl
#     -- models_household/dinnerware/pan_tefal-collision04.obj
#     -- models_household/dinnerware/pan_tefal-collision05.obj
#     -- models_household/dinnerware/pan_tefal-collision01.obj
#     -- models_household/dinnerware/pan_tefal-collision02.obj
#     -- models_household/dinnerware/pan_tefal-collision03.obj
#     -- models_household/dinnerware/pan_tefal.obj
#     -- models_household/dinnerware/plate-collision04.obj
#     -- models_household/dinnerware/plate-collision05.obj
#     -- models_household/dinnerware/plate-collision06.obj
#     -- models_household/dinnerware/plate.urdf
#     -- models_household/dinnerware/plate-collision02.obj
#     -- models_household/dinnerware/plate-collision03.obj
#     -- models_household/dinnerware/plate.obj
#     -- models_household/dinnerware/plate-collision01.obj
#     -- models_household/dinnerware/pan_tefal.urdf
#     -- models_household/woodenbox/woodenbox-collision08.off
#     -- models_household/woodenbox/woodenbox.obj
#     -- models_household/woodenbox/woodenbox-collision09.off
#     -- models_household/woodenbox/woodenbox-collision10.off
#     -- models_household/woodenbox/woodenbox-collision04.off
#     -- models_household/woodenbox/woodenbox_tex.jpg
#     -- models_household/woodenbox/woodenbox-collision05.off
#     -- models_household/woodenbox/woodenbox-collision07.off
#     -- models_household/woodenbox/woodenbox-collision06.off
#     -- models_household/woodenbox/woodenbox-collision02.off
#     -- models_household/woodenbox/woodenbox.mtl
#     -- models_household/woodenbox/woodenbox-collision03.off
#     -- models_household/woodenbox/woodenbox-collision01.off
#     -- models_household/woodenbox/woodenbox-collision00.off
#     -- models_household/tablelamp/tablelamp.obj
#     -- models_household/tablelamp/tablelamp-collision01.off
#     -- models_household/tablelamp/tablelamptex.jpg
#     -- models_household/tablelamp/tablelamp-collision00.off
#     -- models_household/tablelamp/tablelamp-collision02.off
#     -- models_household/tablelamp/tablelamp.obj.mtl
#     -- models_household/joypad/joypad.obj
#     -- models_household/joypad/joypad_tex.jpg
#     -- models_household/joypad/joypad.mtl
#     -- models_household/zucchini/zucchini_tex_green.jpg
#     -- models_household/zucchini/zucchini.obj
#     -- models_household/zucchini/zucchini.mtl
#     -- models_household/bottle/potionbottlesolid.mtl
#     -- models_household/bottle/potionbottleglass.obj
#     -- models_household/bottle/glasscontent_tex.jpg
#     -- models_household/bottle/bottle.urdf
#     -- models_household/bottle/glass_tex.png
#     -- models_household/bottle/potionbottlesolid.obj
#     -- models_household/bottle/potionbottleglass.mtl
#     -- models_household/keyboard/keyboard.obj
#     -- models_household/keyboard/keyboard.mtl
#     -- models_household/keyboard/keyboard_tex.jpg
#     -- models_outdoor/stadium/stadium1.obj
#     -- models_outdoor/stadium/stadium.mtl
#     -- models_outdoor/stadium/stadium_grass.jpg
#     -- models_outdoor/stadium/pong1.obj
#     -- mujoco_assets/reacher.xml
#     -- mujoco_assets/inverted_pendulum.xml
#     -- mujoco_assets/inverted_double_pendulum.xml
#     -- mujoco_assets/half_cheetah.xml
#     -- mujoco_assets/ant.xml
#     -- mujoco_assets/hopper.xml
#     -- mujoco_assets/humanoid_symmetric.xml
#     -- mujoco_assets/walker2d.xml
#     -- mujoco_assets/ground_plane.xml
#     -- models_robot/roboschool_pong.xml
#     -- models_robot/atlas_description/materials/textures/extremities_diffuse_unplugged.jpg
#     -- models_robot/atlas_description/materials/textures/right_leg_diffuse_unplugged.jpg
#     -- models_robot/atlas_description/materials/textures/drc_extremities_diffuse.jpg
#     -- models_robot/atlas_description/materials/textures/torso_diffuse_unplugged.jpg
#     -- models_robot/atlas_description/urdf/atlas_v4_with_multisense.urdf
#     -- models_robot/atlas_description/meshes_v3/r_farm.dae
#     -- models_robot/atlas_description/meshes_v3/r_larm.dae
#     -- models_robot/atlas_description/meshes_v3/r_hand.dae
#     -- models_robot/atlas_description/meshes_unplugged/l_lglut.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_scap.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_lglut.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_uleg.dae
#     -- models_robot/atlas_description/meshes_unplugged/pelvis.dae
#     -- models_robot/atlas_description/meshes_unplugged/l_uleg.dae
#     -- models_robot/atlas_description/meshes_unplugged/l_foot.dae
#     -- models_robot/atlas_description/meshes_unplugged/mtorso.dae
#     -- models_robot/atlas_description/meshes_unplugged/ltorso.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_talus.dae
#     -- models_robot/atlas_description/meshes_unplugged/l_talus.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_foot.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_clav.dae
#     -- models_robot/atlas_description/meshes_unplugged/utorso.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_lleg.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_uglut.dae
#     -- models_robot/atlas_description/meshes_unplugged/l_lleg.dae
#     -- models_robot/atlas_description/meshes_unplugged/l_uglut.dae
#     -- models_robot/atlas_description/meshes_unplugged/r_uarm.dae
#     -- models_robot/multisense_sl_description/materials/textures/drc_torso_head_diffuse.jpg
#     -- models_robot/multisense_sl_description/meshes/head.dae
#     -- models_robot/multisense_sl_description/meshes/head_camera.dae
#     -- models_robot/fetch_description/meshes/torso_lift_link_collision.STL
#     -- models_robot/fetch_description/meshes/l_wheel_link.STL
#     -- models_robot/fetch_description/meshes/bellows_link_collision.STL
#     -- models_robot/fetch_description/meshes/forearm_roll_link.dae
#     -- models_robot/fetch_description/meshes/r_wheel_link_collision.STL
#     -- models_robot/fetch_description/meshes/torso_fixed_link.dae
#     -- models_robot/fetch_description/meshes/gripper_uv.png
#     -- models_robot/fetch_description/meshes/shoulder_lift_link.dae
#     -- models_robot/fetch_description/meshes/head_pan_link.dae
#     -- models_robot/fetch_description/meshes/r_gripper_finger_link.STL
#     -- models_robot/fetch_description/meshes/bellows_link.STL
#     -- models_robot/fetch_description/meshes/elbow_flex_uv.png
#     -- models_robot/fetch_description/meshes/head_pan_uv.png
# ...
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/l_foot.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/mtorso.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/ltorso.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/r_talus.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/l_talus.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/r_foot.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/r_clav.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/utorso.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/r_lleg.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/r_uglut.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/l_lleg.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/l_uglut.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     copying roboschool/models_robot/atlas_description/meshes_unplugged/r_uarm.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/atlas_description/meshes_unplugged
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/materials
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/materials/textures
#     copying roboschool/models_robot/multisense_sl_description/materials/textures/drc_torso_head_diffuse.jpg -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/materials/textures
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/meshes
#     copying roboschool/models_robot/multisense_sl_description/meshes/head.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/meshes
#     copying roboschool/models_robot/multisense_sl_description/meshes/head_camera.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/multisense_sl_description/meshes
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/torso_lift_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/l_wheel_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/bellows_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/forearm_roll_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/r_wheel_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/torso_fixed_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/gripper_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/shoulder_lift_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/head_pan_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/r_gripper_finger_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/bellows_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/elbow_flex_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/head_pan_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/l_gripper_finger_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/estop_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/torso_fixed_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/wrist_roll_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/wrist_flex_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/shoulder_lift_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/upperarm_roll_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/torso_lift_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/upperarm_roll_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/base_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/base_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/shoulder_pan_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/gripper_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/torso_fixed_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/shoulder_pan_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/forearm_roll_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/upperarm_roll_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/r_wheel_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/wrist_flex_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/wrist_roll_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/elbow_flex_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/forearm_roll_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/gripper_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/head_pan_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/laser_link.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/shoulder_lift_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/torso_lift_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/head_tilt_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/wrist_roll_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/head_tilt_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/wrist_flex_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/shoulder_pan_link.dae -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/elbow_flex_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/base_link_uv.png -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/head_tilt_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     copying roboschool/models_robot/fetch_description/meshes/l_wheel_link_collision.STL -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/meshes
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/robots
#     copying roboschool/models_robot/fetch_description/robots/fetch.urdf -> build/lib.macosx-10.9-x86_64-3.8/roboschool/models_robot/fetch_description/robots
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household
#     creating build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     copying roboschool/cpp-household/glsl/simple_texturing.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     copying roboschool/cpp-household/glsl/ssao_hbao_blur.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     copying roboschool/cpp-household/glsl/fullscreen_triangle.vert.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     copying roboschool/cpp-household/glsl/hud.vert.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     copying roboschool/cpp-household/glsl/ssao_hbao.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     copying roboschool/cpp-household/glsl/displaytex.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     copying roboschool/cpp-household/glsl/simple_texturing.vert.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     copying roboschool/cpp-household/glsl/ssao_depthlinearize.frag.glsl -> build/lib.macosx-10.9-x86_64-3.8/roboschool/cpp-household/glsl
#     running build_ext
#     cd /private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/roboschool/cpp-household && make clean && make -j4 dirs  ../cpp_household.so
#     make: *** No rule to make target `clean'.  Stop.
#
#     C++ dependencies for this project are:
#
#     bullet
#     tinyxml
#     boost_python
#     assimp
#     Qt5
#
#     If you see compilation error FIRST THING TO CHECK if pkg-config call was successful.
#     Install dependencies that pkg-config cannot find.
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/setup.py'"'"'; __file__='"'"'/private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-install-pcuugwrp/roboschool_e5a6cf696afb4fa8a515155c84e8d9a0/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/_t/jnfxk4dn49v647llkz4cdy940000gn/T/pip-record-abz7j5qh/install-record.txt --single-version-externally-managed --compile --install-headers /opt/anaconda3/include/python3.8/roboschool Check the logs for full command output.
# Requirement already satisfied: box2d-py in /opt/anaconda3/lib/python3.8/site-packages (2.3.8)
# Requirement already satisfied: Box2D in /opt/anaconda3/lib/python3.8/site-packages (2.3.10)
# Requirement already satisfied: pybullet in /opt/anaconda3/lib/python3.8/site-packages (3.2.5)
# Requirement already satisfied: gym[box2d] in /opt/anaconda3/lib/python3.8/site-packages (0.15.4)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (1.3.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (1.15.0)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (1.8.1)
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (4.5.3.56)
# Requirement already satisfied: numpy>=1.10.4 in /opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (1.23.4)
# Requirement already satisfied: cloudpickle~=1.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (1.2.2)
# Requirement already satisfied: box2d-py~=2.3.5 in /opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (2.3.8)
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.8/site-packages (from pyglet<=1.3.2,>=1.2.0->gym[box2d]) (0.18.2)

# %% [markdown]
# > # **Introduction**
# > Structure of this notebook
#
# *   **Part I** : define actor-critic network and PPO algorithm
# *   **Part II** : train PPO algorithm and save network weights and log files
# *   **Part III** : load (preTrained) network weights and test PPO algorithm
# *   **Part IV** : load log files and plot graphs
# *   **Part V** :  load (preTrained) network weights and save images for gif and then generate gif for the environment visualisation

# %% [markdown]
# > # **Part - I**
#
# *   define actor critic networks
# *   define PPO algorithm

# %%
# Import libraries

import os
import glob
import time
from datetime import datetime

import torch
import torch.nn as nn
from torch.distributions import MultivariateNormal
from torch.distributions import Categorical

import numpy as np

import gym
# version error for this environment that we will not test
#import roboschool
import pybullet_envs


################################## set device ##################################

print("============================================================================================")


# set device to cpu or cuda
device = torch.device('cpu')

if(torch.cuda.is_available()): 
    device = torch.device('cuda:0') 
    torch.cuda.empty_cache()
    print("Device set to : " + str(torch.cuda.get_device_name(device)))
else:
    print("Device set to : cpu")
    
print("============================================================================================")




################################## PPO Policy ##################################


class RolloutBuffer:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.state_values = []
        self.is_terminals = []
    

    def clear(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.state_values[:]
        del self.is_terminals[:]

# actor critic module : define the networks for the two parts
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, has_continuous_action_space, action_std_init):
        super(ActorCritic, self).__init__()

        self.has_continuous_action_space = has_continuous_action_space

        if has_continuous_action_space:
            self.action_dim = action_dim
            self.action_var = torch.full((action_dim,), action_std_init * action_std_init).to(device)

        # actor
        if has_continuous_action_space :
            self.actor = nn.Sequential(
                            nn.Linear(state_dim, 64),
                            nn.Tanh(),
                            nn.Linear(64, 64),
                            nn.Tanh(),
                            nn.Linear(64, action_dim),
                            nn.Tanh()
                        )
        else:
            self.actor = nn.Sequential(
                            nn.Linear(state_dim, 64),
                            nn.Tanh(),
                            nn.Linear(64, 64),
                            nn.Tanh(),
                            nn.Linear(64, action_dim),
                            nn.Softmax(dim=-1)
                        )

        
        # critic
        self.critic = nn.Sequential(
                        nn.Linear(state_dim, 64),
                        nn.Tanh(),
                        nn.Linear(64, 64),
                        nn.Tanh(),
                        nn.Linear(64, 1)
                    )
        
    def set_action_std(self, new_action_std):

        if self.has_continuous_action_space:
            self.action_var = torch.full((self.action_dim,), new_action_std * new_action_std).to(device)
        else:
            print("--------------------------------------------------------------------------------------------")
            print("WARNING : Calling ActorCritic::set_action_std() on discrete action space policy")
            print("--------------------------------------------------------------------------------------------")


    def forward(self):
        raise NotImplementedError
    

    def act(self, state):

        if self.has_continuous_action_space:
            action_mean = self.actor(state)
            cov_mat = torch.diag(self.action_var).unsqueeze(dim=0)
            dist = MultivariateNormal(action_mean, cov_mat)
        else:
            action_probs = self.actor(state)
            dist = Categorical(action_probs)

        action = dist.sample()
        action_logprob = dist.log_prob(action)
        state_val = self.critic(state)

        return action.detach(), action_logprob.detach(), state_val.detach()
    

    def evaluate(self, state, action):

        if self.has_continuous_action_space:
            action_mean = self.actor(state)
            action_var = self.action_var.expand_as(action_mean)
            cov_mat = torch.diag_embed(action_var).to(device)
            dist = MultivariateNormal(action_mean, cov_mat)
            
            # for single action continuous environments
            if self.action_dim == 1:
                action = action.reshape(-1, self.action_dim)

        else:
            action_probs = self.actor(state)
            dist = Categorical(action_probs)

        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        state_values = self.critic(state)
        
        return action_logprobs, state_values, dist_entropy

# class to implement proximal policy optimisation
class PPO:
    def __init__(self, state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip, has_continuous_action_space, action_std_init=0.6):

        self.has_continuous_action_space = has_continuous_action_space

        if has_continuous_action_space:
            self.action_std = action_std_init

        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.buffer = RolloutBuffer()

        self.policy = ActorCritic(state_dim, action_dim, has_continuous_action_space, action_std_init).to(device)
        self.optimizer = torch.optim.Adam([
                        {'params': self.policy.actor.parameters(), 'lr': lr_actor},
                        {'params': self.policy.critic.parameters(), 'lr': lr_critic}
                    ])

        self.policy_old = ActorCritic(state_dim, action_dim, has_continuous_action_space, action_std_init).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        
        self.MseLoss = nn.MSELoss()


    def set_action_std(self, new_action_std):
        
        if self.has_continuous_action_space:
            self.action_std = new_action_std
            self.policy.set_action_std(new_action_std)
            self.policy_old.set_action_std(new_action_std)
        
        else:
            print("--------------------------------------------------------------------------------------------")
            print("WARNING : Calling PPO::set_action_std() on discrete action space policy")
            print("--------------------------------------------------------------------------------------------")


    def decay_action_std(self, action_std_decay_rate, min_action_std):
        print("--------------------------------------------------------------------------------------------")

        if self.has_continuous_action_space:
            self.action_std = self.action_std - action_std_decay_rate
            self.action_std = round(self.action_std, 4)
            if (self.action_std <= min_action_std):
                self.action_std = min_action_std
                print("setting actor output action_std to min_action_std : ", self.action_std)
            else:
                print("setting actor output action_std to : ", self.action_std)
            self.set_action_std(self.action_std)

        else:
            print("WARNING : Calling PPO::decay_action_std() on discrete action space policy")

        print("--------------------------------------------------------------------------------------------")


    def select_action(self, state):

        if self.has_continuous_action_space:
            with torch.no_grad():
                state = torch.FloatTensor(state).to(device)
                action, action_logprob, state_val = self.policy_old.act(state)

            self.buffer.states.append(state)
            self.buffer.actions.append(action)
            self.buffer.logprobs.append(action_logprob)
            self.buffer.state_values.append(state_val)

            return action.detach().cpu().numpy().flatten()

        else:
            with torch.no_grad():
                state = torch.FloatTensor(state).to(device)
                action, action_logprob, state_val = self.policy_old.act(state)
            
            self.buffer.states.append(state)
            self.buffer.actions.append(action)
            self.buffer.logprobs.append(action_logprob)
            self.buffer.state_values.append(state_val)

            return action.item()


    def update(self):

        # Monte Carlo estimate of returns
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(self.buffer.rewards), reversed(self.buffer.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
            
        # Normalizing the rewards
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-7)

        # convert list to tensor
        old_states = torch.squeeze(torch.stack(self.buffer.states, dim=0)).detach().to(device)
        old_actions = torch.squeeze(torch.stack(self.buffer.actions, dim=0)).detach().to(device)
        old_logprobs = torch.squeeze(torch.stack(self.buffer.logprobs, dim=0)).detach().to(device)
        old_state_values = torch.squeeze(torch.stack(self.buffer.state_values, dim=0)).detach().to(device)

        # calculate advantages
        advantages = rewards.detach() - old_state_values.detach()
        

        # Optimize policy for K epochs
        for _ in range(self.K_epochs):

            # Evaluating old actions and values
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions)

            # match state_values tensor dimensions with rewards tensor
            state_values = torch.squeeze(state_values)
            
            # Finding the ratio (pi_theta / pi_theta__old)
            ratios = torch.exp(logprobs - old_logprobs.detach())

            # Finding Surrogate Loss   
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages

            # final loss of clipped objective PPO
            loss = -torch.min(surr1, surr2) + 0.5 * self.MseLoss(state_values, rewards) - 0.01 * dist_entropy
            
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
        # Copy new weights into old policy
        self.policy_old.load_state_dict(self.policy.state_dict())

        # clear buffer
        self.buffer.clear()
    
    
    def save(self, checkpoint_path):
        torch.save(self.policy_old.state_dict(), checkpoint_path)
   

    def load(self, checkpoint_path):
        self.policy_old.load_state_dict(torch.load(checkpoint_path, map_location=lambda storage, loc: storage))
        self.policy.load_state_dict(torch.load(checkpoint_path, map_location=lambda storage, loc: storage))
# Out:
# ============================================================================================
# Device set to : cpu
# ============================================================================================

# %% [markdown]
# > # **Part - II**
#
# *   train PPO algorithm on environments
# *   save preTrained networks weights and log files

# %% [markdown]
# *** WARNING : choose the cell corresponding to your environment***

# %% [markdown]
# CartPole

# %%
####### initialize environment hyperparameters ######

env_name = "CartPole-v1"
has_continuous_action_space = False

max_ep_len = 400                    # max timesteps in one episode
max_training_timesteps = int(1e5)   # break training loop if timeteps > max_training_timesteps

print_freq = max_ep_len * 4     # print avg reward in the interval (in num timesteps)
log_freq = max_ep_len * 2       # log avg reward in the interval (in num timesteps)
save_model_freq = int(2e4)      # save model frequency (in num timesteps)

action_std = None

################ PPO hyperparameters ################


update_timestep = max_ep_len * 4      # update policy every n timesteps
K_epochs = 40               # update policy for K epochs
eps_clip = 0.2              # clip parameter for PPO
gamma = 0.99                # discount factor

lr_actor = 0.0003       # learning rate for actor network
lr_critic = 0.001       # learning rate for critic network

random_seed = 0         # set random seed if required (0 = no random seed)

#####################################################

# %% [markdown]
# Lunar Lander

# %%
####### initialize environment hyperparameters ######

env_name = "LunarLander-v2"
has_continuous_action_space = False

max_ep_len = 300                   # max timesteps in one episode
max_training_timesteps = int(1e6)   # break training loop if timeteps > max_training_timesteps

print_freq = max_ep_len * 8                # print avg reward in the interval (in num timesteps)
log_freq = max_ep_len * 2                  # log avg reward in the interval (in num timesteps)
save_model_freq = int(5e4)      # save model frequency (in num timesteps)

action_std = None

################ PPO hyperparameters ################

update_timestep = max_ep_len * 3      # update policy every n timesteps
K_epochs = 30               # update policy for K epochs
eps_clip = 0.2              # clip parameter for PPO
gamma = 0.99                # discount factor

lr_actor = 0.0003       # learning rate for actor network
lr_critic = 0.001       # learning rate for critic network

random_seed = 0         # set random seed if required (0 = no random seed)

#####################################################

# %% [markdown]
# Bipedal Walker

# %%
################################### Training ###################################

####### initialize environment hyperparameters ######

env_name = "BipedalWalker-v2"

has_continuous_action_space = True

max_ep_len = 1500                   # max timesteps in one episode
max_training_timesteps = int(3e6)   # break training loop if timeteps > max_training_timesteps

print_freq = max_ep_len * 4               # print avg reward in the interval (in num timesteps)
log_freq = max_ep_len * 2                 # log avg reward in the interval (in num timesteps)
save_model_freq = int(1e5)      # save model frequency (in num timesteps)

action_std = 0.6                    # starting std for action distribution (Multivariate Normal)
action_std_decay_rate = 0.05        # linearly decay action_std (action_std = action_std - action_std_decay_rate)
min_action_std = 0.1                # minimum action_std (stop decay after action_std <= min_action_std)
action_std_decay_freq = int(2.5e5)  # action_std decay frequency (in num timesteps)

################ PPO hyperparameters ################

update_timestep = max_ep_len * 4      # update policy every n timesteps
K_epochs = 80               # update policy for K epochs in one PPO update

eps_clip = 0.2          # clip parameter for PPO
gamma = 0.99            # discount factor

lr_actor = 0.0003       # learning rate for actor network
lr_critic = 0.001       # learning rate for critic network

random_seed = 0         # set random seed if required (0 = no random seed)

#####################################################

# %%
print("training environment name : " + env_name)

env = gym.make(env_name)

# state space dimension
state_dim = env.observation_space.shape[0]

# action space dimension
if has_continuous_action_space:
    action_dim = env.action_space.shape[0]
else:
    action_dim = env.action_space.n



###################### logging ######################

#### log files for multiple runs are NOT overwritten

log_dir = "PPO_logs"
if not os.path.exists(log_dir):
      os.makedirs(log_dir)

log_dir = log_dir + '/' + env_name + '/'
if not os.path.exists(log_dir):
      os.makedirs(log_dir)


#### get number of log files in log directory
run_num = 0
current_num_files = next(os.walk(log_dir))[2]
run_num = len(current_num_files)


#### create new log file for each run 
log_f_name = log_dir + '/PPO_' + env_name + "_log_" + str(run_num) + ".csv"

print("current logging run number for " + env_name + " : ", run_num)
print("logging at : " + log_f_name)

#####################################################


################### checkpointing ###################

run_num_pretrained = 0      #### change this to prevent overwriting weights in same env_name folder

directory = "PPO_preTrained"
if not os.path.exists(directory):
      os.makedirs(directory)

directory = directory + '/' + env_name + '/'
if not os.path.exists(directory):
      os.makedirs(directory)


checkpoint_path = directory + "PPO_{}_{}_{}.pth".format(env_name, random_seed, run_num_pretrained)
print("save checkpoint path : " + checkpoint_path)

#####################################################


############# print all hyperparameters #############

print("--------------------------------------------------------------------------------------------")

print("max training timesteps : ", max_training_timesteps)
print("max timesteps per episode : ", max_ep_len)

print("model saving frequency : " + str(save_model_freq) + " timesteps")
print("log frequency : " + str(log_freq) + " timesteps")
print("printing average reward over episodes in last : " + str(print_freq) + " timesteps")

print("--------------------------------------------------------------------------------------------")

print("state space dimension : ", state_dim)
print("action space dimension : ", action_dim)

print("--------------------------------------------------------------------------------------------")

if has_continuous_action_space:
    print("Initializing a continuous action space policy")
    print("--------------------------------------------------------------------------------------------")
    print("starting std of action distribution : ", action_std)
    print("decay rate of std of action distribution : ", action_std_decay_rate)
    print("minimum std of action distribution : ", min_action_std)
    print("decay frequency of std of action distribution : " + str(action_std_decay_freq) + " timesteps")

else:
    print("Initializing a discrete action space policy")

print("--------------------------------------------------------------------------------------------")

print("PPO update frequency : " + str(update_timestep) + " timesteps") 
print("PPO K epochs : ", K_epochs)
print("PPO epsilon clip : ", eps_clip)
print("discount factor (gamma) : ", gamma)

print("--------------------------------------------------------------------------------------------")

print("optimizer learning rate actor : ", lr_actor)
print("optimizer learning rate critic : ", lr_critic)

if random_seed:
    print("--------------------------------------------------------------------------------------------")
    print("setting random seed to ", random_seed)
    torch.manual_seed(random_seed)
    env.seed(random_seed)
    np.random.seed(random_seed)

#####################################################

print("============================================================================================")

################# training procedure ################

# initialize a PPO agent
ppo_agent = PPO(state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip, has_continuous_action_space, action_std)


# track total training time
start_time = datetime.now().replace(microsecond=0)
print("Started training at (GMT) : ", start_time)

print("============================================================================================")


# logging file
log_f = open(log_f_name,"w+")
log_f.write('episode,timestep,reward\n')


# printing and logging variables
print_running_reward = 0
print_running_episodes = 0

log_running_reward = 0
log_running_episodes = 0

time_step = 0
i_episode = 0


# training loop
while time_step <= max_training_timesteps:
    
    state = env.reset()
    current_ep_reward = 0

    for t in range(1, max_ep_len+1):
        
        # select action with policy
        action = ppo_agent.select_action(state)
        state, reward, done, _ = env.step(action)
        
        # saving reward and is_terminals
        ppo_agent.buffer.rewards.append(reward)
        ppo_agent.buffer.is_terminals.append(done)
        
        time_step +=1
        current_ep_reward += reward

        # update PPO agent
        if time_step % update_timestep == 0:
            ppo_agent.update()

        # if continuous action space; then decay action std of ouput action distribution
        if has_continuous_action_space and time_step % action_std_decay_freq == 0:
            ppo_agent.decay_action_std(action_std_decay_rate, min_action_std)

        # log in logging file
        if time_step % log_freq == 0:

            # log average reward till last episode
            log_avg_reward = log_running_reward / log_running_episodes
            log_avg_reward = round(log_avg_reward, 4)

            log_f.write('{},{},{}\n'.format(i_episode, time_step, log_avg_reward))
            log_f.flush()

            log_running_reward = 0
            log_running_episodes = 0

        # printing average reward
        if time_step % print_freq == 0:

            # print average reward till last episode
            print_avg_reward = print_running_reward / print_running_episodes
            print_avg_reward = round(print_avg_reward, 2)

            print("Episode : {} \t\t Timestep : {} \t\t Average Reward : {}".format(i_episode, time_step, print_avg_reward))

            print_running_reward = 0
            print_running_episodes = 0
            
        # save model weights
        if time_step % save_model_freq == 0:
            print("--------------------------------------------------------------------------------------------")
            print("saving model at : " + checkpoint_path)
            ppo_agent.save(checkpoint_path)
            print("model saved")
            print("Elapsed Time  : ", datetime.now().replace(microsecond=0) - start_time)
            print("--------------------------------------------------------------------------------------------")
            
        # break; if the episode is over
        if done:
            break

    print_running_reward += current_ep_reward
    print_running_episodes += 1

    log_running_reward += current_ep_reward
    log_running_episodes += 1

    i_episode += 1


log_f.close()
env.close()


# print total training time
print("============================================================================================")
end_time = datetime.now().replace(microsecond=0)
print("Started training at (GMT) : ", start_time)
print("Finished training at (GMT) : ", end_time)
print("Total training time  : ", end_time - start_time)
print("============================================================================================")
# Out:
# training environment name : LunarLander-v2
# current logging run number for LunarLander-v2 :  2
# logging at : PPO_logs/LunarLander-v2//PPO_LunarLander-v2_log_2.csv
# save checkpoint path : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# --------------------------------------------------------------------------------------------
# max training timesteps :  1000000
# max timesteps per episode :  300
# model saving frequency : 50000 timesteps
# log frequency : 600 timesteps
# printing average reward over episodes in last : 2400 timesteps
# --------------------------------------------------------------------------------------------
# state space dimension :  8
# action space dimension :  4
# --------------------------------------------------------------------------------------------
# Initializing a discrete action space policy
# --------------------------------------------------------------------------------------------
# PPO update frequency : 900 timesteps
# PPO K epochs :  30
# PPO epsilon clip :  0.3
# discount factor (gamma) :  0.99
# --------------------------------------------------------------------------------------------
# optimizer learning rate actor :  0.0003
# optimizer learning rate critic :  0.001
# ============================================================================================
# Started training at (GMT) :  2023-01-25 22:03:09
# ============================================================================================
# Episode : 26 		 Timestep : 2400 		 Average Reward : -224.39
# Episode : 54 		 Timestep : 4800 		 Average Reward : -155.98
# Episode : 85 		 Timestep : 7200 		 Average Reward : -135.34
# Episode : 115 		 Timestep : 9600 		 Average Reward : -128.89
# Episode : 145 		 Timestep : 12000 		 Average Reward : -142.56
# Episode : 173 		 Timestep : 14400 		 Average Reward : -114.94
# Episode : 199 		 Timestep : 16800 		 Average Reward : -118.55
# Episode : 224 		 Timestep : 19200 		 Average Reward : -82.78
# Episode : 247 		 Timestep : 21600 		 Average Reward : -66.47
# Episode : 271 		 Timestep : 24000 		 Average Reward : -71.73
# Episode : 296 		 Timestep : 26400 		 Average Reward : -66.79
# Episode : 317 		 Timestep : 28800 		 Average Reward : -15.23
# Episode : 329 		 Timestep : 31200 		 Average Reward : 19.01
# Episode : 341 		 Timestep : 33600 		 Average Reward : -15.69
# Episode : 355 		 Timestep : 36000 		 Average Reward : 12.13
# Episode : 366 		 Timestep : 38400 		 Average Reward : 35.86
# Episode : 381 		 Timestep : 40800 		 Average Reward : 11.58
# Episode : 394 		 Timestep : 43200 		 Average Reward : 46.27
# Episode : 404 		 Timestep : 45600 		 Average Reward : 60.08
# Episode : 415 		 Timestep : 48000 		 Average Reward : -27.88
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:00:43
# --------------------------------------------------------------------------------------------
# Episode : 427 		 Timestep : 50400 		 Average Reward : 21.55
# Episode : 438 		 Timestep : 52800 		 Average Reward : 17.97
# Episode : 450 		 Timestep : 55200 		 Average Reward : -0.08
# Episode : 461 		 Timestep : 57600 		 Average Reward : 26.74
# Episode : 471 		 Timestep : 60000 		 Average Reward : 38.31
# Episode : 480 		 Timestep : 62400 		 Average Reward : 62.28
# Episode : 489 		 Timestep : 64800 		 Average Reward : 72.39
# Episode : 497 		 Timestep : 67200 		 Average Reward : 68.79
# Episode : 505 		 Timestep : 69600 		 Average Reward : 120.64
# Episode : 514 		 Timestep : 72000 		 Average Reward : 69.04
# Episode : 523 		 Timestep : 74400 		 Average Reward : 111.11
# Episode : 532 		 Timestep : 76800 		 Average Reward : 68.55
# Episode : 543 		 Timestep : 79200 		 Average Reward : 72.4
# Episode : 552 		 Timestep : 81600 		 Average Reward : 96.07
# Episode : 560 		 Timestep : 84000 		 Average Reward : 64.6
# Episode : 570 		 Timestep : 86400 		 Average Reward : 103.74
# Episode : 580 		 Timestep : 88800 		 Average Reward : 78.8
# Episode : 589 		 Timestep : 91200 		 Average Reward : 98.02
# Episode : 599 		 Timestep : 93600 		 Average Reward : 75.31
# Episode : 609 		 Timestep : 96000 		 Average Reward : 97.77
# Episode : 621 		 Timestep : 98400 		 Average Reward : 69.65
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:01:30
# --------------------------------------------------------------------------------------------
# Episode : 634 		 Timestep : 100800 		 Average Reward : 38.95
# Episode : 645 		 Timestep : 103200 		 Average Reward : 76.08
# Episode : 655 		 Timestep : 105600 		 Average Reward : 81.56
# Episode : 667 		 Timestep : 108000 		 Average Reward : 50.54
# Episode : 675 		 Timestep : 110400 		 Average Reward : 123.29
# Episode : 684 		 Timestep : 112800 		 Average Reward : 131.28
# Episode : 693 		 Timestep : 115200 		 Average Reward : 87.92
# Episode : 702 		 Timestep : 117600 		 Average Reward : 116.35
# Episode : 710 		 Timestep : 120000 		 Average Reward : 150.08
# Episode : 721 		 Timestep : 122400 		 Average Reward : 113.09
# Episode : 732 		 Timestep : 124800 		 Average Reward : 108.19
# Episode : 741 		 Timestep : 127200 		 Average Reward : 115.82
# Episode : 750 		 Timestep : 129600 		 Average Reward : 118.47
# Episode : 760 		 Timestep : 132000 		 Average Reward : 113.39
# Episode : 769 		 Timestep : 134400 		 Average Reward : 71.38
# Episode : 779 		 Timestep : 136800 		 Average Reward : 73.77
# Episode : 789 		 Timestep : 139200 		 Average Reward : 78.11
# Episode : 799 		 Timestep : 141600 		 Average Reward : 24.46
# Episode : 807 		 Timestep : 144000 		 Average Reward : 129.11
# Episode : 816 		 Timestep : 146400 		 Average Reward : 116.51
# Episode : 825 		 Timestep : 148800 		 Average Reward : 120.2
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:02:16
# --------------------------------------------------------------------------------------------
# Episode : 835 		 Timestep : 151200 		 Average Reward : 67.34
# Episode : 844 		 Timestep : 153600 		 Average Reward : 118.08
# Episode : 856 		 Timestep : 156000 		 Average Reward : 50.99
# Episode : 867 		 Timestep : 158400 		 Average Reward : 99.8
# Episode : 877 		 Timestep : 160800 		 Average Reward : 114.79
# Episode : 886 		 Timestep : 163200 		 Average Reward : 86.39
# Episode : 896 		 Timestep : 165600 		 Average Reward : 76.95
# Episode : 905 		 Timestep : 168000 		 Average Reward : 70.29
# Episode : 914 		 Timestep : 170400 		 Average Reward : 136.51
# Episode : 923 		 Timestep : 172800 		 Average Reward : 83.38
# Episode : 932 		 Timestep : 175200 		 Average Reward : 76.85
# Episode : 941 		 Timestep : 177600 		 Average Reward : 113.95
# Episode : 949 		 Timestep : 180000 		 Average Reward : 130.75
# Episode : 957 		 Timestep : 182400 		 Average Reward : 119.38
# Episode : 966 		 Timestep : 184800 		 Average Reward : 105.03
# Episode : 975 		 Timestep : 187200 		 Average Reward : 77.79
# Episode : 983 		 Timestep : 189600 		 Average Reward : 144.53
# Episode : 991 		 Timestep : 192000 		 Average Reward : 159.25
# Episode : 1000 		 Timestep : 194400 		 Average Reward : 102.81
# Episode : 1008 		 Timestep : 196800 		 Average Reward : 96.45
# Episode : 1017 		 Timestep : 199200 		 Average Reward : 86.35
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:02:58
# --------------------------------------------------------------------------------------------
# Episode : 1025 		 Timestep : 201600 		 Average Reward : 62.03
# Episode : 1033 		 Timestep : 204000 		 Average Reward : 114.66
# Episode : 1041 		 Timestep : 206400 		 Average Reward : 122.34
# Episode : 1051 		 Timestep : 208800 		 Average Reward : 106.05
# Episode : 1061 		 Timestep : 211200 		 Average Reward : 87.84
# Episode : 1071 		 Timestep : 213600 		 Average Reward : 113.95
# Episode : 1080 		 Timestep : 216000 		 Average Reward : 99.61
# Episode : 1089 		 Timestep : 218400 		 Average Reward : 129.44
# Episode : 1099 		 Timestep : 220800 		 Average Reward : 94.87
# Episode : 1109 		 Timestep : 223200 		 Average Reward : 68.34
# Episode : 1118 		 Timestep : 225600 		 Average Reward : 145.24
# Episode : 1127 		 Timestep : 228000 		 Average Reward : 111.08
# Episode : 1137 		 Timestep : 230400 		 Average Reward : 88.68
# Episode : 1149 		 Timestep : 232800 		 Average Reward : 64.01
# Episode : 1159 		 Timestep : 235200 		 Average Reward : 94.78
# Episode : 1168 		 Timestep : 237600 		 Average Reward : 103.06
# Episode : 1178 		 Timestep : 240000 		 Average Reward : 112.96
# Episode : 1187 		 Timestep : 242400 		 Average Reward : 104.5
# Episode : 1195 		 Timestep : 244800 		 Average Reward : 138.19
# Episode : 1204 		 Timestep : 247200 		 Average Reward : 112.2
# Episode : 1213 		 Timestep : 249600 		 Average Reward : 109.85
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:03:41
# --------------------------------------------------------------------------------------------
# Episode : 1222 		 Timestep : 252000 		 Average Reward : 135.66
# Episode : 1230 		 Timestep : 254400 		 Average Reward : 153.98
# Episode : 1238 		 Timestep : 256800 		 Average Reward : 133.29
# Episode : 1249 		 Timestep : 259200 		 Average Reward : 91.68
# Episode : 1258 		 Timestep : 261600 		 Average Reward : 126.92
# Episode : 1268 		 Timestep : 264000 		 Average Reward : 90.95
# Episode : 1277 		 Timestep : 266400 		 Average Reward : 155.87
# Episode : 1286 		 Timestep : 268800 		 Average Reward : 91.13
# Episode : 1295 		 Timestep : 271200 		 Average Reward : 139.91
# Episode : 1303 		 Timestep : 273600 		 Average Reward : 142.03
# Episode : 1313 		 Timestep : 276000 		 Average Reward : 93.66
# Episode : 1324 		 Timestep : 278400 		 Average Reward : 79.8
# Episode : 1334 		 Timestep : 280800 		 Average Reward : 147.77
# Episode : 1344 		 Timestep : 283200 		 Average Reward : 90.36
# Episode : 1353 		 Timestep : 285600 		 Average Reward : 124.73
# Episode : 1363 		 Timestep : 288000 		 Average Reward : 114.91
# Episode : 1372 		 Timestep : 290400 		 Average Reward : 147.61
# Episode : 1382 		 Timestep : 292800 		 Average Reward : 139.09
# Episode : 1391 		 Timestep : 295200 		 Average Reward : 133.35
# Episode : 1399 		 Timestep : 297600 		 Average Reward : 171.21
# Episode : 1407 		 Timestep : 300000 		 Average Reward : 158.94
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:04:23
# --------------------------------------------------------------------------------------------
# Episode : 1416 		 Timestep : 302400 		 Average Reward : 127.67
# Episode : 1425 		 Timestep : 304800 		 Average Reward : 144.84
# Episode : 1434 		 Timestep : 307200 		 Average Reward : 150.75
# Episode : 1442 		 Timestep : 309600 		 Average Reward : 131.78
# Episode : 1452 		 Timestep : 312000 		 Average Reward : 117.47
# Episode : 1462 		 Timestep : 314400 		 Average Reward : 99.91
# Episode : 1472 		 Timestep : 316800 		 Average Reward : 113.45
# Episode : 1483 		 Timestep : 319200 		 Average Reward : 78.88
# Episode : 1492 		 Timestep : 321600 		 Average Reward : 143.48
# Episode : 1501 		 Timestep : 324000 		 Average Reward : 134.11
# Episode : 1510 		 Timestep : 326400 		 Average Reward : 154.26
# Episode : 1518 		 Timestep : 328800 		 Average Reward : 156.91
# Episode : 1528 		 Timestep : 331200 		 Average Reward : 118.88
# Episode : 1536 		 Timestep : 333600 		 Average Reward : 172.5
# Episode : 1545 		 Timestep : 336000 		 Average Reward : 85.81
# Episode : 1553 		 Timestep : 338400 		 Average Reward : 145.98
# Episode : 1561 		 Timestep : 340800 		 Average Reward : 174.87
# Episode : 1569 		 Timestep : 343200 		 Average Reward : 164.33
# Episode : 1578 		 Timestep : 345600 		 Average Reward : 142.52
# Episode : 1586 		 Timestep : 348000 		 Average Reward : 174.09
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:05:02
# --------------------------------------------------------------------------------------------
# Episode : 1595 		 Timestep : 350400 		 Average Reward : 153.86
# Episode : 1604 		 Timestep : 352800 		 Average Reward : 145.35
# Episode : 1615 		 Timestep : 355200 		 Average Reward : 113.9
# Episode : 1625 		 Timestep : 357600 		 Average Reward : 121.89
# Episode : 1635 		 Timestep : 360000 		 Average Reward : 114.92
# Episode : 1644 		 Timestep : 362400 		 Average Reward : 122.31
# Episode : 1653 		 Timestep : 364800 		 Average Reward : 158.32
# Episode : 1661 		 Timestep : 367200 		 Average Reward : 138.95
# Episode : 1670 		 Timestep : 369600 		 Average Reward : 145.07
# Episode : 1681 		 Timestep : 372000 		 Average Reward : 85.28
# Episode : 1692 		 Timestep : 374400 		 Average Reward : 104.44
# Episode : 1703 		 Timestep : 376800 		 Average Reward : 73.31
# Episode : 1718 		 Timestep : 379200 		 Average Reward : 71.68
# Episode : 1729 		 Timestep : 381600 		 Average Reward : 79.62
# Episode : 1739 		 Timestep : 384000 		 Average Reward : 124.23
# Episode : 1750 		 Timestep : 386400 		 Average Reward : 107.76
# Episode : 1761 		 Timestep : 388800 		 Average Reward : 92.77
# Episode : 1774 		 Timestep : 391200 		 Average Reward : 63.41
# Episode : 1782 		 Timestep : 393600 		 Average Reward : 166.58
# Episode : 1792 		 Timestep : 396000 		 Average Reward : 119.3
# Episode : 1805 		 Timestep : 398400 		 Average Reward : 73.27
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:05:41
# --------------------------------------------------------------------------------------------
# Episode : 1816 		 Timestep : 400800 		 Average Reward : 92.5
# Episode : 1828 		 Timestep : 403200 		 Average Reward : 119.75
# Episode : 1837 		 Timestep : 405600 		 Average Reward : 136.4
# Episode : 1848 		 Timestep : 408000 		 Average Reward : 154.97
# Episode : 1859 		 Timestep : 410400 		 Average Reward : 127.91
# Episode : 1869 		 Timestep : 412800 		 Average Reward : 106.38
# Episode : 1879 		 Timestep : 415200 		 Average Reward : 110.58
# Episode : 1890 		 Timestep : 417600 		 Average Reward : 99.37
# Episode : 1900 		 Timestep : 420000 		 Average Reward : 105.92
# Episode : 1911 		 Timestep : 422400 		 Average Reward : 85.99
# Episode : 1919 		 Timestep : 424800 		 Average Reward : 131.05
# Episode : 1930 		 Timestep : 427200 		 Average Reward : 103.79
# Episode : 1938 		 Timestep : 429600 		 Average Reward : 145.44
# Episode : 1948 		 Timestep : 432000 		 Average Reward : 114.3
# Episode : 1958 		 Timestep : 434400 		 Average Reward : 127.79
# Episode : 1970 		 Timestep : 436800 		 Average Reward : 92.95
# Episode : 1978 		 Timestep : 439200 		 Average Reward : 165.16
# Episode : 1991 		 Timestep : 441600 		 Average Reward : 81.7
# Episode : 2000 		 Timestep : 444000 		 Average Reward : 141.04
# Episode : 2008 		 Timestep : 446400 		 Average Reward : 180.84
# Episode : 2017 		 Timestep : 448800 		 Average Reward : 161.28
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:06:21
# --------------------------------------------------------------------------------------------
# Episode : 2029 		 Timestep : 451200 		 Average Reward : 81.3
# Episode : 2038 		 Timestep : 453600 		 Average Reward : 138.53
# Episode : 2048 		 Timestep : 456000 		 Average Reward : 125.95
# Episode : 2058 		 Timestep : 458400 		 Average Reward : 123.08
# Episode : 2069 		 Timestep : 460800 		 Average Reward : 133.68
# Episode : 2078 		 Timestep : 463200 		 Average Reward : 149.97
# Episode : 2089 		 Timestep : 465600 		 Average Reward : 104.05
# Episode : 2100 		 Timestep : 468000 		 Average Reward : 71.46
# Episode : 2110 		 Timestep : 470400 		 Average Reward : 128.3
# Episode : 2120 		 Timestep : 472800 		 Average Reward : 111.11
# Episode : 2130 		 Timestep : 475200 		 Average Reward : 105.88
# Episode : 2139 		 Timestep : 477600 		 Average Reward : 171.06
# Episode : 2147 		 Timestep : 480000 		 Average Reward : 166.85
# Episode : 2157 		 Timestep : 482400 		 Average Reward : 121.73
# Episode : 2166 		 Timestep : 484800 		 Average Reward : 157.8
# Episode : 2176 		 Timestep : 487200 		 Average Reward : 114.4
# Episode : 2185 		 Timestep : 489600 		 Average Reward : 134.18
# Episode : 2195 		 Timestep : 492000 		 Average Reward : 163.58
# Episode : 2203 		 Timestep : 494400 		 Average Reward : 170.63
# Episode : 2213 		 Timestep : 496800 		 Average Reward : 127.83
# Episode : 2222 		 Timestep : 499200 		 Average Reward : 164.26
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:07:00
# --------------------------------------------------------------------------------------------
# Episode : 2230 		 Timestep : 501600 		 Average Reward : 168.54
# Episode : 2241 		 Timestep : 504000 		 Average Reward : 126.65
# Episode : 2252 		 Timestep : 506400 		 Average Reward : 88.35
# Episode : 2260 		 Timestep : 508800 		 Average Reward : 145.14
# Episode : 2269 		 Timestep : 511200 		 Average Reward : 160.51
# Episode : 2279 		 Timestep : 513600 		 Average Reward : 153.12
# Episode : 2290 		 Timestep : 516000 		 Average Reward : 74.05
# Episode : 2301 		 Timestep : 518400 		 Average Reward : 112.01
# Episode : 2311 		 Timestep : 520800 		 Average Reward : 99.14
# Episode : 2323 		 Timestep : 523200 		 Average Reward : 88.79
# Episode : 2333 		 Timestep : 525600 		 Average Reward : 141.35
# Episode : 2345 		 Timestep : 528000 		 Average Reward : 126.58
# Episode : 2356 		 Timestep : 530400 		 Average Reward : 74.9
# Episode : 2370 		 Timestep : 532800 		 Average Reward : 90.57
# Episode : 2381 		 Timestep : 535200 		 Average Reward : 155.21
# Episode : 2393 		 Timestep : 537600 		 Average Reward : 168.89
# Episode : 2406 		 Timestep : 540000 		 Average Reward : 171.38
# Episode : 2417 		 Timestep : 542400 		 Average Reward : 155.56
# Episode : 2429 		 Timestep : 544800 		 Average Reward : 157.36
# Episode : 2441 		 Timestep : 547200 		 Average Reward : 142.66
# Episode : 2451 		 Timestep : 549600 		 Average Reward : 123.89
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:07:37
# --------------------------------------------------------------------------------------------
# Episode : 2461 		 Timestep : 552000 		 Average Reward : 225.57
# Episode : 2473 		 Timestep : 554400 		 Average Reward : 213.72
# Episode : 2484 		 Timestep : 556800 		 Average Reward : 142.96
# Episode : 2493 		 Timestep : 559200 		 Average Reward : 155.65
# Episode : 2504 		 Timestep : 561600 		 Average Reward : 166.56
# Episode : 2514 		 Timestep : 564000 		 Average Reward : 216.08
# Episode : 2524 		 Timestep : 566400 		 Average Reward : 187.1
# Episode : 2535 		 Timestep : 568800 		 Average Reward : 230.3
# Episode : 2548 		 Timestep : 571200 		 Average Reward : 143.42
# Episode : 2560 		 Timestep : 573600 		 Average Reward : 187.76
# Episode : 2571 		 Timestep : 576000 		 Average Reward : 222.13
# Episode : 2583 		 Timestep : 578400 		 Average Reward : 187.39
# Episode : 2596 		 Timestep : 580800 		 Average Reward : 158.24
# Episode : 2609 		 Timestep : 583200 		 Average Reward : 128.19
# Episode : 2622 		 Timestep : 585600 		 Average Reward : 196.19
# Episode : 2634 		 Timestep : 588000 		 Average Reward : 169.85
# Episode : 2644 		 Timestep : 590400 		 Average Reward : 119.03
# Episode : 2654 		 Timestep : 592800 		 Average Reward : 108.36
# Episode : 2664 		 Timestep : 595200 		 Average Reward : 110.56
# Episode : 2672 		 Timestep : 597600 		 Average Reward : 152.36
# Episode : 2680 		 Timestep : 600000 		 Average Reward : 168.25
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:08:14
# --------------------------------------------------------------------------------------------
# Episode : 2689 		 Timestep : 602400 		 Average Reward : 115.64
# Episode : 2699 		 Timestep : 604800 		 Average Reward : 164.34
# Episode : 2708 		 Timestep : 607200 		 Average Reward : 155.95
# Episode : 2723 		 Timestep : 609600 		 Average Reward : 50.76
# Episode : 2737 		 Timestep : 612000 		 Average Reward : 60.58
# Episode : 2750 		 Timestep : 614400 		 Average Reward : 89.72
# Episode : 2761 		 Timestep : 616800 		 Average Reward : 66.46
# Episode : 2771 		 Timestep : 619200 		 Average Reward : 137.73
# Episode : 2783 		 Timestep : 621600 		 Average Reward : 74.82
# Episode : 2793 		 Timestep : 624000 		 Average Reward : 118.0
# Episode : 2804 		 Timestep : 626400 		 Average Reward : 131.34
# Episode : 2818 		 Timestep : 628800 		 Average Reward : 63.95
# Episode : 2833 		 Timestep : 631200 		 Average Reward : 90.09
# Episode : 2843 		 Timestep : 633600 		 Average Reward : 128.86
# Episode : 2857 		 Timestep : 636000 		 Average Reward : 86.49
# Episode : 2876 		 Timestep : 638400 		 Average Reward : 53.14
# Episode : 2896 		 Timestep : 640800 		 Average Reward : 62.6
# Episode : 2914 		 Timestep : 643200 		 Average Reward : 66.84
# Episode : 2930 		 Timestep : 645600 		 Average Reward : 30.9
# Episode : 2946 		 Timestep : 648000 		 Average Reward : 86.4
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:08:53
# --------------------------------------------------------------------------------------------
# Episode : 2962 		 Timestep : 650400 		 Average Reward : 107.33
# Episode : 2981 		 Timestep : 652800 		 Average Reward : 42.14
# Episode : 2994 		 Timestep : 655200 		 Average Reward : 67.11
# Episode : 3013 		 Timestep : 657600 		 Average Reward : 30.75
# Episode : 3025 		 Timestep : 660000 		 Average Reward : 68.43
# Episode : 3044 		 Timestep : 662400 		 Average Reward : 27.23
# Episode : 3058 		 Timestep : 664800 		 Average Reward : 58.9
# Episode : 3075 		 Timestep : 667200 		 Average Reward : 31.77
# Episode : 3093 		 Timestep : 669600 		 Average Reward : 23.92
# Episode : 3107 		 Timestep : 672000 		 Average Reward : 54.98
# Episode : 3121 		 Timestep : 674400 		 Average Reward : 73.61
# Episode : 3132 		 Timestep : 676800 		 Average Reward : 92.8
# Episode : 3145 		 Timestep : 679200 		 Average Reward : 63.95
# Episode : 3157 		 Timestep : 681600 		 Average Reward : 91.25
# Episode : 3172 		 Timestep : 684000 		 Average Reward : 47.97
# Episode : 3187 		 Timestep : 686400 		 Average Reward : 52.28
# Episode : 3200 		 Timestep : 688800 		 Average Reward : 61.88
# Episode : 3218 		 Timestep : 691200 		 Average Reward : 32.31
# Episode : 3232 		 Timestep : 693600 		 Average Reward : 62.59
# Episode : 3246 		 Timestep : 696000 		 Average Reward : 59.83
# Episode : 3258 		 Timestep : 698400 		 Average Reward : 65.59
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:09:34
# --------------------------------------------------------------------------------------------
# Episode : 3274 		 Timestep : 700800 		 Average Reward : 41.47
# Episode : 3287 		 Timestep : 703200 		 Average Reward : 85.14
# Episode : 3298 		 Timestep : 705600 		 Average Reward : 100.53
# Episode : 3310 		 Timestep : 708000 		 Average Reward : 89.52
# Episode : 3320 		 Timestep : 710400 		 Average Reward : 91.68
# Episode : 3334 		 Timestep : 712800 		 Average Reward : 69.05
# Episode : 3344 		 Timestep : 715200 		 Average Reward : 105.61
# Episode : 3354 		 Timestep : 717600 		 Average Reward : 89.61
# Episode : 3362 		 Timestep : 720000 		 Average Reward : 117.96
# Episode : 3373 		 Timestep : 722400 		 Average Reward : 82.34
# Episode : 3385 		 Timestep : 724800 		 Average Reward : 69.91
# Episode : 3397 		 Timestep : 727200 		 Average Reward : 87.57
# Episode : 3409 		 Timestep : 729600 		 Average Reward : 69.21
# Episode : 3420 		 Timestep : 732000 		 Average Reward : 68.69
# Episode : 3432 		 Timestep : 734400 		 Average Reward : 72.16
# Episode : 3441 		 Timestep : 736800 		 Average Reward : 106.66
# Episode : 3453 		 Timestep : 739200 		 Average Reward : 61.97
# Episode : 3466 		 Timestep : 741600 		 Average Reward : 46.48
# Episode : 3475 		 Timestep : 744000 		 Average Reward : 99.1
# Episode : 3486 		 Timestep : 746400 		 Average Reward : 97.23
# Episode : 3496 		 Timestep : 748800 		 Average Reward : 114.28
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:10:18
# --------------------------------------------------------------------------------------------
# Episode : 3510 		 Timestep : 751200 		 Average Reward : 42.95
# Episode : 3521 		 Timestep : 753600 		 Average Reward : 80.05
# Episode : 3531 		 Timestep : 756000 		 Average Reward : 98.9
# Episode : 3543 		 Timestep : 758400 		 Average Reward : 61.5
# Episode : 3555 		 Timestep : 760800 		 Average Reward : 72.84
# Episode : 3566 		 Timestep : 763200 		 Average Reward : 133.61
# Episode : 3576 		 Timestep : 765600 		 Average Reward : 117.07
# Episode : 3588 		 Timestep : 768000 		 Average Reward : 83.85
# Episode : 3599 		 Timestep : 770400 		 Average Reward : 72.6
# Episode : 3612 		 Timestep : 772800 		 Average Reward : 48.92
# Episode : 3622 		 Timestep : 775200 		 Average Reward : 107.09
# Episode : 3631 		 Timestep : 777600 		 Average Reward : 94.76
# Episode : 3639 		 Timestep : 780000 		 Average Reward : 170.51
# Episode : 3651 		 Timestep : 782400 		 Average Reward : 89.39
# Episode : 3660 		 Timestep : 784800 		 Average Reward : 129.71
# Episode : 3671 		 Timestep : 787200 		 Average Reward : 86.3
# Episode : 3686 		 Timestep : 789600 		 Average Reward : 56.11
# Episode : 3698 		 Timestep : 792000 		 Average Reward : 77.51
# Episode : 3709 		 Timestep : 794400 		 Average Reward : 84.47
# Episode : 3719 		 Timestep : 796800 		 Average Reward : 97.69
# Episode : 3730 		 Timestep : 799200 		 Average Reward : 74.16
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:11:01
# --------------------------------------------------------------------------------------------
# Episode : 3742 		 Timestep : 801600 		 Average Reward : 89.01
# Episode : 3753 		 Timestep : 804000 		 Average Reward : 149.15
# Episode : 3766 		 Timestep : 806400 		 Average Reward : 134.43
# Episode : 3776 		 Timestep : 808800 		 Average Reward : 143.03
# Episode : 3790 		 Timestep : 811200 		 Average Reward : 86.05
# Episode : 3800 		 Timestep : 813600 		 Average Reward : 116.81
# Episode : 3814 		 Timestep : 816000 		 Average Reward : 120.44
# Episode : 3823 		 Timestep : 818400 		 Average Reward : 91.26
# Episode : 3835 		 Timestep : 820800 		 Average Reward : 71.04
# Episode : 3843 		 Timestep : 823200 		 Average Reward : 102.43
# Episode : 3852 		 Timestep : 825600 		 Average Reward : 98.98
# Episode : 3860 		 Timestep : 828000 		 Average Reward : 125.11
# Episode : 3868 		 Timestep : 830400 		 Average Reward : 102.03
# Episode : 3879 		 Timestep : 832800 		 Average Reward : 84.58
# Episode : 3887 		 Timestep : 835200 		 Average Reward : 73.42
# Episode : 3895 		 Timestep : 837600 		 Average Reward : 118.81
# Episode : 3907 		 Timestep : 840000 		 Average Reward : 96.93
# Episode : 3915 		 Timestep : 842400 		 Average Reward : 134.99
# Episode : 3927 		 Timestep : 844800 		 Average Reward : 130.87
# Episode : 3935 		 Timestep : 847200 		 Average Reward : 132.02
# Episode : 3944 		 Timestep : 849600 		 Average Reward : 212.7
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:11:45
# --------------------------------------------------------------------------------------------
# Episode : 3954 		 Timestep : 852000 		 Average Reward : 195.48
# Episode : 3966 		 Timestep : 854400 		 Average Reward : 239.71
# Episode : 3977 		 Timestep : 856800 		 Average Reward : 153.33
# Episode : 3989 		 Timestep : 859200 		 Average Reward : 124.23
# Episode : 3999 		 Timestep : 861600 		 Average Reward : 205.85
# Episode : 4009 		 Timestep : 864000 		 Average Reward : 198.11
# Episode : 4022 		 Timestep : 866400 		 Average Reward : 110.47
# Episode : 4033 		 Timestep : 868800 		 Average Reward : 197.87
# Episode : 4043 		 Timestep : 871200 		 Average Reward : 136.04
# Episode : 4054 		 Timestep : 873600 		 Average Reward : 157.54
# Episode : 4067 		 Timestep : 876000 		 Average Reward : 146.64
# Episode : 4080 		 Timestep : 878400 		 Average Reward : 117.87
# Episode : 4093 		 Timestep : 880800 		 Average Reward : 128.48
# Episode : 4104 		 Timestep : 883200 		 Average Reward : 83.27
# Episode : 4115 		 Timestep : 885600 		 Average Reward : 87.28
# Episode : 4125 		 Timestep : 888000 		 Average Reward : 109.87
# Episode : 4133 		 Timestep : 890400 		 Average Reward : 123.19
# Episode : 4142 		 Timestep : 892800 		 Average Reward : 89.58
# Episode : 4152 		 Timestep : 895200 		 Average Reward : 113.78
# Episode : 4161 		 Timestep : 897600 		 Average Reward : 110.46
# Episode : 4171 		 Timestep : 900000 		 Average Reward : 140.22
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:12:27
# --------------------------------------------------------------------------------------------
# Episode : 4181 		 Timestep : 902400 		 Average Reward : 141.13
# Episode : 4191 		 Timestep : 904800 		 Average Reward : 107.26
# Episode : 4202 		 Timestep : 907200 		 Average Reward : 86.31
# Episode : 4213 		 Timestep : 909600 		 Average Reward : 100.03
# Episode : 4224 		 Timestep : 912000 		 Average Reward : 65.43
# Episode : 4233 		 Timestep : 914400 		 Average Reward : 162.22
# Episode : 4247 		 Timestep : 916800 		 Average Reward : 55.83
# Episode : 4259 		 Timestep : 919200 		 Average Reward : 107.04
# Episode : 4268 		 Timestep : 921600 		 Average Reward : 152.18
# Episode : 4280 		 Timestep : 924000 		 Average Reward : 113.37
# Episode : 4290 		 Timestep : 926400 		 Average Reward : 121.6
# Episode : 4303 		 Timestep : 928800 		 Average Reward : 134.96
# Episode : 4314 		 Timestep : 931200 		 Average Reward : 128.69
# Episode : 4325 		 Timestep : 933600 		 Average Reward : 184.16
# Episode : 4338 		 Timestep : 936000 		 Average Reward : 92.19
# Episode : 4352 		 Timestep : 938400 		 Average Reward : 60.35
# Episode : 4367 		 Timestep : 940800 		 Average Reward : 100.74
# Episode : 4378 		 Timestep : 943200 		 Average Reward : 222.37
# Episode : 4388 		 Timestep : 945600 		 Average Reward : 132.93
# Episode : 4400 		 Timestep : 948000 		 Average Reward : 142.31
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:13:08
# --------------------------------------------------------------------------------------------
# Episode : 4413 		 Timestep : 950400 		 Average Reward : 97.5
# Episode : 4426 		 Timestep : 952800 		 Average Reward : 171.69
# Episode : 4437 		 Timestep : 955200 		 Average Reward : 183.12
# Episode : 4446 		 Timestep : 957600 		 Average Reward : 133.63
# Episode : 4456 		 Timestep : 960000 		 Average Reward : 145.54
# Episode : 4467 		 Timestep : 962400 		 Average Reward : 174.9
# Episode : 4479 		 Timestep : 964800 		 Average Reward : 135.91
# Episode : 4489 		 Timestep : 967200 		 Average Reward : 120.61
# Episode : 4499 		 Timestep : 969600 		 Average Reward : 179.73
# Episode : 4509 		 Timestep : 972000 		 Average Reward : 106.79
# Episode : 4522 		 Timestep : 974400 		 Average Reward : 101.41
# Episode : 4532 		 Timestep : 976800 		 Average Reward : 201.87
# Episode : 4541 		 Timestep : 979200 		 Average Reward : 195.13
# Episode : 4551 		 Timestep : 981600 		 Average Reward : 196.51
# Episode : 4561 		 Timestep : 984000 		 Average Reward : 215.61
# Episode : 4571 		 Timestep : 986400 		 Average Reward : 216.82
# Episode : 4580 		 Timestep : 988800 		 Average Reward : 133.23
# Episode : 4592 		 Timestep : 991200 		 Average Reward : 191.3
# Episode : 4604 		 Timestep : 993600 		 Average Reward : 210.01
# Episode : 4615 		 Timestep : 996000 		 Average Reward : 81.06
# Episode : 4626 		 Timestep : 998400 		 Average Reward : 153.87
# --------------------------------------------------------------------------------------------
# saving model at : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_2.pth
# model saved
# Elapsed Time  :  0:13:48
# --------------------------------------------------------------------------------------------
# ============================================================================================
# Started training at (GMT) :  2023-01-25 22:03:09
# Finished training at (GMT) :  2023-01-25 22:16:57
# Total training time  :  0:13:48
# ============================================================================================

# %% [markdown]
# > # **Part - III**
#
# *   load and test preTrained networks on environments

# %%
print("============================================================================================")
#################################### Testing ###################################

################## hyperparameters ##################
# NB : load the correct hyperparameters and check env_name

# env_name = "CartPole-v1"
# env_name = "LunarLander-v2"
# env_name = "BipedalWalker-v2"

total_test_episodes = 10    # total num of testing episodes

env = gym.make(env_name)

# state space dimension
state_dim = env.observation_space.shape[0]

# action space dimension
if has_continuous_action_space:
    action_dim = env.action_space.shape[0]
else:
    action_dim = env.action_space.n


# initialize a PPO agent
ppo_agent = PPO(state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip, has_continuous_action_space, action_std)


# preTrained weights directory

random_seed = 0             #### set this to load a particular checkpoint trained on random seed
run_num_pretrained = 0      #### set this to load a particular checkpoint num


directory = "PPO_preTrained" + '/' + env_name + '/'
checkpoint_path = directory + "PPO_{}_{}_{}.pth".format(env_name, random_seed, run_num_pretrained)
print("loading network from : " + checkpoint_path)

ppo_agent.load(checkpoint_path)

print("--------------------------------------------------------------------------------------------")


test_running_reward = 0

for ep in range(1, total_test_episodes+1):
    ep_reward = 0
    state = env.reset()
    
    for t in range(1, max_ep_len+1):
        action = ppo_agent.select_action(state)
        state, reward, done, _ = env.step(action)
        ep_reward += reward
        
        if done:
            break

    # clear buffer    
    ppo_agent.buffer.clear()

    test_running_reward +=  ep_reward
    print('Episode: {} \t\t Reward: {}'.format(ep, round(ep_reward, 2)))
    ep_reward = 0

env.close()

print("============================================================================================")

avg_test_reward = test_running_reward / total_test_episodes
avg_test_reward = round(avg_test_reward, 2)
print("average test reward : " + str(avg_test_reward))

print("============================================================================================")
# Out:
# ============================================================================================
# loading network from : PPO_preTrained/LunarLander-v2/PPO_LunarLander-v2_0_0.pth
# --------------------------------------------------------------------------------------------
# Episode: 1 		 Reward: 55.86
# Episode: 2 		 Reward: 178.2
# Episode: 3 		 Reward: 111.33
# Episode: 4 		 Reward: 179.18
# Episode: 5 		 Reward: 153.23
# Episode: 6 		 Reward: 133.38
# Episode: 7 		 Reward: 137.91
# Episode: 8 		 Reward: -13.24
# Episode: 9 		 Reward: 133.9
# Episode: 10 		 Reward: -34.81
# ============================================================================================
# average test reward : 103.49
# ============================================================================================

# %% [markdown]
# > # **Part - IV**
#
# *   load log files using pandas
# *   plot graph using matplotlib

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


print("============================================================================================")

# env_name = "CartPole-v1"
# env_name = "LunarLander-v2"
# env_name = "BipedalWalker-v2"

fig_num = 0     #### change this to prevent overwriting figures in same env_name folder

plot_avg = False    # plot average of all runs; else plot all runs separately

fig_width = 10
fig_height = 6


# smooth out rewards to get a smooth and a less smooth (var) plot lines
window_len_smooth = 50
min_window_len_smooth = 1
linewidth_smooth = 1.5
alpha_smooth = 1

window_len_var = 5
min_window_len_var = 1
linewidth_var = 2
alpha_var = 0.1


colors = ['red', 'blue', 'green', 'orange', 'purple', 'olive', 'brown', 'magenta', 'cyan', 'crimson','gray', 'black']


# make directory for saving figures
figures_dir = "PPO_figs"
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)

# make environment directory for saving figures
figures_dir = figures_dir + '/' + env_name + '/'
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)


fig_save_path = figures_dir + '/PPO_' + env_name + '_fig_' + str(fig_num) + '.png'


# get number of log files in directory
log_dir = "PPO_logs" + '/' + env_name + '/'

current_num_files = next(os.walk(log_dir))[2]
num_runs = len(current_num_files)


all_runs = []

for run_num in range(num_runs):

    log_f_name = log_dir + '/PPO_' + env_name + "_log_" + str(run_num) + ".csv"
    print("loading data from : " + log_f_name)
    data = pd.read_csv(log_f_name)
    data = pd.DataFrame(data)
    
    print("data shape : ", data.shape)
    
    all_runs.append(data)
    print("--------------------------------------------------------------------------------------------")


ax = plt.gca()

if plot_avg:
    # average all runs
    df_concat = pd.concat(all_runs)
    df_concat_groupby = df_concat.groupby(df_concat.index)
    data_avg = df_concat_groupby.mean()

    # smooth out rewards to get a smooth and a less smooth (var) plot lines
    data_avg['reward_smooth'] = data_avg['reward'].rolling(window=window_len_smooth, win_type='triang', min_periods=min_window_len_smooth).mean()
    data_avg['reward_var'] = data_avg['reward'].rolling(window=window_len_var, win_type='triang', min_periods=min_window_len_var).mean()

    data_avg.plot(kind='line', x='timestep' , y='reward_smooth',ax=ax,color=colors[0],  linewidth=linewidth_smooth, alpha=alpha_smooth)
    data_avg.plot(kind='line', x='timestep' , y='reward_var',ax=ax,color=colors[0],  linewidth=linewidth_var, alpha=alpha_var)

    # keep only reward_smooth in the legend and rename it
    handles, labels = ax.get_legend_handles_labels()
    ax.legend([handles[0]], ["reward_avg_" + str(len(all_runs)) + "_runs"], loc=2)


else:
    for i, run in enumerate(all_runs):
        # smooth out rewards to get a smooth and a less smooth (var) plot lines
        run['reward_smooth_' + str(i)] = run['reward'].rolling(window=window_len_smooth, win_type='triang', min_periods=min_window_len_smooth).mean()
        run['reward_var_' + str(i)] = run['reward'].rolling(window=window_len_var, win_type='triang', min_periods=min_window_len_var).mean()
        
        # plot the lines
        run.plot(kind='line', x='timestep' , y='reward_smooth_' + str(i),ax=ax,color=colors[i % len(colors)],  linewidth=linewidth_smooth, alpha=alpha_smooth)
        run.plot(kind='line', x='timestep' , y='reward_var_' + str(i),ax=ax,color=colors[i % len(colors)],  linewidth=linewidth_var, alpha=alpha_var)

    # keep alternate elements (reward_smooth_i) in the legend
    handles, labels = ax.get_legend_handles_labels()
    new_handles = []
    new_labels = []
    for i in range(len(handles)):
        if(i%2 == 0):
            new_handles.append(handles[i])
            new_labels.append(labels[i])
    ax.legend(new_handles, new_labels, loc=2)



# ax.set_yticks(np.arange(0, 1800, 200))
# ax.set_xticks(np.arange(0, int(4e6), int(5e5)))


ax.grid(color='gray', linestyle='-', linewidth=1, alpha=0.2)

ax.set_xlabel("Timesteps", fontsize=12)
ax.set_ylabel("Rewards", fontsize=12)

plt.title(env_name, fontsize=14)


fig = plt.gcf()
fig.set_size_inches(fig_width, fig_height)

print("============================================================================================")

plt.savefig(fig_save_path)
print("figure saved at : ", fig_save_path)

print("============================================================================================")


plt.show()
# Out:
# ============================================================================================
# loading data from : PPO_logs/LunarLander-v2//PPO_LunarLander-v2_log_0.csv
# data shape :  (1666, 3)
# --------------------------------------------------------------------------------------------
# loading data from : PPO_logs/LunarLander-v2//PPO_LunarLander-v2_log_1.csv
# data shape :  (1666, 3)
# --------------------------------------------------------------------------------------------
# loading data from : PPO_logs/LunarLander-v2//PPO_LunarLander-v2_log_2.csv
# data shape :  (1666, 3)
# --------------------------------------------------------------------------------------------
# ============================================================================================
# figure saved at :  PPO_figs/LunarLander-v2//PPO_LunarLander-v2_fig_3.png
# ============================================================================================

# %% [markdown]
# > # **Part - V**
#
# *   install virtual display libraries for rendering on colab / remote server
# *   load preTrained networks and save images for gif
# *   generate and save gif from previously saved images

# %%
#### to render on colab / server / headless machine install virtual display libraries
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %%
############################# save images for gif ##############################

import os
import glob

import gym
# import roboschool
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from IPython import display as ipythondisplay

from pyvirtualdisplay import Display

"""
One frame corresponding to each timestep is saved in a folder :

PPO_gif_images/env_name/000001.jpg
PPO_gif_images/env_name/000002.jpg
PPO_gif_images/env_name/000003.jpg
...
...
...

if this section is run multiple times or for multiple episodes for the same env_name; 
then the saved images will be overwritten.
"""

#### beginning of virtual display code section
display = Display(visible=0, size=(400, 300))
display.start()
#### end of virtual display code section

print("============================================================================================")

################## hyperparameters ##################
# NB : choose the correct hyperparameters
total_test_episodes = 1     # save gif for only one episode

render_ipython = False      # plot the images using matplotlib and ipythondisplay before saving (slow)

env = gym.make(env_name)

# state space dimension
state_dim = env.observation_space.shape[0]

# action space dimension
if has_continuous_action_space:
    action_dim = env.action_space.shape[0]
else:
    action_dim = env.action_space.n

# make directory for saving gif images
gif_images_dir = "PPO_gif_images" + '/'
if not os.path.exists(gif_images_dir):
    os.makedirs(gif_images_dir)

# make environment directory for saving gif images
gif_images_dir = gif_images_dir + '/' + env_name + '/'
if not os.path.exists(gif_images_dir):
    os.makedirs(gif_images_dir)

# make directory for gif
gif_dir = "PPO_gifs" + '/'
if not os.path.exists(gif_dir):
    os.makedirs(gif_dir)

# make environment directory for gif
gif_dir = gif_dir + '/' + env_name  + '/'
if not os.path.exists(gif_dir):
    os.makedirs(gif_dir)

ppo_agent = PPO(state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip, has_continuous_action_space, action_std)

# preTrained weights directory

random_seed = 0             #### set this to load a particular checkpoint trained on random seed
run_num_pretrained = 0      #### set this to load a particular checkpoint num

directory = "PPO_preTrained" + '/' + env_name + '/'
checkpoint_path = directory + "PPO_{}_{}_{}.pth".format(env_name, random_seed, run_num_pretrained)
print("loading network from : " + checkpoint_path)

ppo_agent.load(checkpoint_path)

print("--------------------------------------------------------------------------------------------")

test_running_reward = 0

for ep in range(1, total_test_episodes+1):
    
    ep_reward = 0
    state = env.reset()

    for t in range(1, max_ep_len+1):
        action = ppo_agent.select_action(state)
        state, reward, done, _ = env.step(action)
        ep_reward += reward

        img = env.render(mode = 'rgb_array')

        #### beginning of ipythondisplay code section 1
        if render_ipython:
            plt.imshow(img)
            ipythondisplay.clear_output(wait=True)
            ipythondisplay.display(plt.gcf())
        #### end of ipythondisplay code section 1


        img = Image.fromarray(img)
        img.save(gif_images_dir + '/' + str(t).zfill(6) + '.jpg')
        
        if done:
            break
    
    # clear buffer    
    ppo_agent.buffer.clear()
    
    test_running_reward +=  ep_reward
    print('Episode: {} \t\t Reward: {}'.format(ep, round(ep_reward, 2)))
    ep_reward = 0

env.close()


#### beginning of ipythondisplay code section 2
if render_ipython:
    ipythondisplay.clear_output(wait=True)
#### end of ipythondisplay code section 2


print("============================================================================================")

print("total number of frames / timesteps / images saved : ", t)

avg_test_reward = test_running_reward / total_test_episodes
avg_test_reward = round(avg_test_reward, 2)
print("average test reward : " + str(avg_test_reward))

print("============================================================================================")
# Out:
# ============================================================================================
# loading network from : PPO_preTrained/BipedalWalker-v2/PPO_BipedalWalker-v2_0_0.pth
# --------------------------------------------------------------------------------------------
# Episode: 1 		 Reward: 121.98
# ============================================================================================
# total number of frames / timesteps / images saved :  1500
# average test reward : 121.98
# ============================================================================================

# %%
######################## generate gif from saved images ########################

print("============================================================================================")

# env_name = 'CartPole-v1'
# env_name = 'LunarLander-v2'
# env_name = 'BipedalWalker-v2'


gif_num = 0     #### change this to prevent overwriting gifs in same env_name folder

# adjust following parameters to get desired duration, size (bytes) and smoothness of gif
total_timesteps = 300
step = 10
frame_duration = 150


# input images
gif_images_dir = "PPO_gif_images/" + env_name + '/*.jpg'


# output gif path
gif_dir = "PPO_gifs"
if not os.path.exists(gif_dir):
    os.makedirs(gif_dir)

gif_dir = gif_dir + '/' + env_name
if not os.path.exists(gif_dir):
    os.makedirs(gif_dir)

gif_path = gif_dir + '/PPO_' + env_name + '_gif_' + str(gif_num) + '.gif'

img_paths = sorted(glob.glob(gif_images_dir))
img_paths = img_paths[:total_timesteps]
img_paths = img_paths[::step]

print("total frames in gif : ", len(img_paths))
print("total duration of gif : " + str(round(len(img_paths) * frame_duration / 1000, 2)) + " seconds")

# save gif
img, *imgs = [Image.open(f) for f in img_paths]
img.save(fp=gif_path, format='GIF', append_images=imgs, save_all=True, optimize=True, duration=frame_duration, loop=0)

print("saved gif at : ", gif_path)

print("============================================================================================")
# Out:
# ============================================================================================
# total frames in gif :  30
# total duration of gif : 4.5 seconds
# saved gif at :  PPO_gifs/BipedalWalker-v2/PPO_BipedalWalker-v2_gif_0.gif
# ============================================================================================

# %%
############################# check gif byte size ##############################
import os
import glob

print("============================================================================================")

gif_dir = "PPO_gifs/" + env_name + '/*.gif'

gif_paths = sorted(glob.glob(gif_dir))

for gif_path in gif_paths:
    file_size = os.path.getsize(gif_path)
    print(gif_path + '\t\t' + str(round(file_size / (1024 * 1024), 2)) + " MB")

print("============================================================================================")
# Out:
# ============================================================================================
# PPO_gifs/BipedalWalker-v2/PPO_BipedalWalker-v2_gif_0.gif		6.87 MB
# ============================================================================================

# %%
# !zip -r PPO_preTrained.zip /content/PPO_preTrained
# Out:
#   adding: content/PPO_preTrained/ (stored 0%)
#   adding: content/PPO_preTrained/BipedalWalker-v2/ (stored 0%)
#   adding: content/PPO_preTrained/BipedalWalker-v2/PPO_BipedalWalker-v2_0_0.pth (deflated 12%)

# %%
from google.colab import files
files.download('PPO_preTrained.zip')

# %%
# !zip -r PPO_logs.zip /content/PPO_logs
files.download('PPO_logs.zip')
# Out:
#   adding: content/PPO_logs/ (stored 0%)
#   adding: content/PPO_logs/BipedalWalker-v2/ (stored 0%)
#   adding: content/PPO_logs/BipedalWalker-v2/PPO_BipedalWalker-v2_log_0.csv (deflated 56%)

# %%
# !zip -r PPO_figs.zip /content/PPO_figs
files.download('PPO_figs.zip')
# Out:
#   adding: content/PPO_figs/ (stored 0%)
#   adding: content/PPO_figs/CartPole-v1/ (stored 0%)
#   adding: content/PPO_figs/BipedalWalker-v2/ (stored 0%)
#   adding: content/PPO_figs/BipedalWalker-v2/PPO_BipedalWalker-v2_fig_0.png (deflated 5%)

# %%
# !zip -r PPO_gifs.zip /content/PPO_gifs
files.download('PPO_gifs.zip')
# Out:
#   adding: content/PPO_gifs/ (stored 0%)
#   adding: content/PPO_gifs/BipedalWalker-v2/ (stored 0%)
#   adding: content/PPO_gifs/BipedalWalker-v2/PPO_BipedalWalker-v2_gif_0.gif (deflated 90%)
